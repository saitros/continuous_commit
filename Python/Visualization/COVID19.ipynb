# %% [markdown]
# # Import Library

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import random
import math
import time
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import datetime
import operator 
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# # Import Dataset
#
# https://github.com/CSSEGISandData/COVID-19

# %%
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
recoveries_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
latest_data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-14-2020.csv')

# %% [markdown]
# # Preview Dataset

# %%
# 확진자
confirmed_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/14/20  4/15/20  4/16/20
# 0            NaN    Afghanistan  33.0000  ...      714      784      840
# 1            NaN        Albania  41.1533  ...      475      494      518
# 2            NaN        Algeria  28.0339  ...     2070     2160     2268
# 3            NaN        Andorra  42.5063  ...      659      673      673
# 4            NaN         Angola -11.2027  ...       19       19       19
#
# [5 rows x 90 columns]

# %%
# 사망자
deaths_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/14/20  4/15/20  4/16/20
# 0            NaN    Afghanistan  33.0000  ...       23       25       30
# 1            NaN        Albania  41.1533  ...       24       25       26
# 2            NaN        Algeria  28.0339  ...      326      336      348
# 3            NaN        Andorra  42.5063  ...       31       33       33
# 4            NaN         Angola -11.2027  ...        2        2        2
#
# [5 rows x 90 columns]

# %%
# 완치
recoveries_df.head()
# Out:
#   Province/State Country/Region      Lat  ...  4/14/20  4/15/20  4/16/20
# 0            NaN    Afghanistan  33.0000  ...       40       43       54
# 1            NaN        Albania  41.1533  ...      248      251      277
# 2            NaN        Algeria  28.0339  ...      691      708      783
# 3            NaN        Andorra  42.5063  ...      128      169      169
# 4            NaN         Angola -11.2027  ...        5        5        5
#
# [5 rows x 90 columns]

# %%
# 확진 죽음 완치 Active(코로나 감염자)
latest_data.head()
# Out:
#       FIPS     Admin2  ... Active                   Combined_Key
# 0  45001.0  Abbeville  ...      9  Abbeville, South Carolina, US
# 1  22001.0     Acadia  ...     99          Acadia, Louisiana, US
# 2  51001.0   Accomack  ...     15         Accomack, Virginia, US
# 3  16001.0        Ada  ...    529                 Ada, Idaho, US
# 4  19001.0      Adair  ...      1                Adair, Iowa, US
#
# [5 rows x 12 columns]

# %%
# 총 185개국에 대해서 데이터가 존재 

len(set(list(latest_data['Country_Region'])))
# Out:
# 185

# %% [markdown]
# # Pandas Dataframe

# %% [markdown]
# ## 국가별 통계

# %%
unique_countries =  list(latest_data['Country_Region'].unique())

# %%
country_confirmed_cases = []
country_death_cases = [] 
country_active_cases = []
country_recovery_cases = []
country_mortality_rate = [] 

no_cases = []
for i in unique_countries:
    cases = latest_data[latest_data['Country_Region']==i]['Confirmed'].sum()
    if cases > 0:
        country_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
        
for i in no_cases:
    unique_countries.remove(i)
    
# sort countries by the number of confirmed cases
unique_countries = [k for k, v in sorted(zip(unique_countries, country_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_countries)):
    country_confirmed_cases[i] = latest_data[latest_data['Country_Region']==unique_countries[i]]['Confirmed'].sum()
    country_death_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Deaths'].sum())
    country_recovery_cases.append(latest_data[latest_data['Country_Region']==unique_countries[i]]['Recovered'].sum())
    country_active_cases.append(country_confirmed_cases[i] - country_death_cases[i] - country_recovery_cases[i])
    country_mortality_rate.append(country_death_cases[i]/country_confirmed_cases[i])

# %%
country_df = pd.DataFrame({'Country Name': unique_countries, 'Number of Confirmed Cases': country_confirmed_cases,
                          'Number of Deaths': country_death_cases, 'Number of Recoveries' : country_recovery_cases, 
                          'Number of Active Cases' : country_active_cases,
                          'Mortality Rate': country_mortality_rate})
# number of cases per country/region

country_df.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_88c4f378_80ac_11ea_9678_0242ac1c0002row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row0_col3 {
#             background-color:  #46ae60;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row0_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row0_col5 {
#             background-color:  #d6efd0;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row1_col1 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row1_col2 {
#             background-color:  #2f984f;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row1_col3 {
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row1_col4 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row1_col5 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row2_col1 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row2_col2 {
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row2_col3 {
#             background-color:  #7dc87e;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row2_col4 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row2_col5 {
#             background-color:  #52b365;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row3_col1 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row3_col2 {
#             background-color:  #46ae60;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row3_col3 {
#             background-color:  #a2d99c;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row3_col4 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row3_col5 {
#             background-color:  #63bc6e;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row4_col1 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row4_col2 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row4_col3 {
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row4_col4 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row4_col5 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row5_col1 {
#             background-color:  #def2d9;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row5_col2 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row5_col3 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row5_col4 {
#             background-color:  #def2d9;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row5_col5 {
#             background-color:  #55b567;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row6_col1 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row6_col2 {
#             background-color:  #e4f5df;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row6_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row6_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row6_col5 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row7_col1 {
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row7_col2 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row7_col3 {
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row7_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row7_col5 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row8_col1 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row8_col2 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row8_col3 {
#             background-color:  #eff9eb;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row8_col4 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row8_col5 {
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row9_col1 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row9_col2 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row9_col3 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row9_col4 {
#             background-color:  #f2faef;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row9_col5 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row10_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row10_col2 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row10_col3 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row10_col4 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row10_col5 {
#             background-color:  #7ac77b;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row11_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row11_col2 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row11_col3 {
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row11_col4 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_88c4f378_80ac_11ea_9678_0242ac1c0002row11_col5 {
#             background-color:  #dff3da;
#             color:  #0

# %% [markdown]
# ## 지역별 통계

# %%
unique_provinces =  list(latest_data['Province_State'].unique())

# %%
province_confirmed_cases = []
province_country = [] 
province_death_cases = [] 
province_recovery_cases = []
province_mortality_rate = [] 

no_cases = [] 
for i in unique_provinces:
    cases = latest_data[latest_data['Province_State']==i]['Confirmed'].sum()
    if cases > 0:
        province_confirmed_cases.append(cases)
    else:
        no_cases.append(i)
 
# remove areas with no confirmed cases
for i in no_cases:
    unique_provinces.remove(i)
    
unique_provinces = [k for k, v in sorted(zip(unique_provinces, province_confirmed_cases), key=operator.itemgetter(1), reverse=True)]
for i in range(len(unique_provinces)):
    province_confirmed_cases[i] = latest_data[latest_data['Province_State']==unique_provinces[i]]['Confirmed'].sum()
    province_country.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Country_Region'].unique()[0])
    province_death_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Deaths'].sum())
    province_recovery_cases.append(latest_data[latest_data['Province_State']==unique_provinces[i]]['Recovered'].sum())
    province_mortality_rate.append(province_death_cases[i]/province_confirmed_cases[i])

# %%
province_df = pd.DataFrame({'Province/State Name': unique_provinces, 'Country': province_country, 'Number of Confirmed Cases': province_confirmed_cases,
                          'Number of Deaths': province_death_cases, 'Number of Recoveries' : province_recovery_cases,
                          'Mortality Rate': province_mortality_rate})
# number of cases per country/region

province_df.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_895c8008_80ac_11ea_9678_0242ac1c0002row0_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row0_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row0_col5 {
#             background-color:  #bae3b3;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row1_col2 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row1_col3 {
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row1_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row1_col5 {
#             background-color:  #cdecc7;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row2_col2 {
#             background-color:  #aedea7;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row2_col3 {
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row2_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row2_col5 {
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row3_col2 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row3_col3 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row3_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row3_col5 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row4_col2 {
#             background-color:  #e3f4de;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row4_col3 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row4_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row4_col5 {
#             background-color:  #a5db9f;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row5_col2 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row5_col3 {
#             background-color:  #eef8ea;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row5_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row5_col5 {
#             background-color:  #dff3da;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row6_col2 {
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row6_col3 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row6_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row6_col5 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row7_col2 {
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row7_col3 {
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row7_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row7_col5 {
#             background-color:  #d2edcc;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row8_col2 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row8_col3 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row8_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row8_col5 {
#             background-color:  #e0f3db;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row9_col2 {
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row9_col3 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row9_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row9_col5 {
#             background-color:  #c4e8bd;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row10_col2 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row10_col3 {
#             background-color:  #f2faf0;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row10_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row10_col5 {
#             background-color:  #e5f5e0;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row11_col2 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row11_col3 {
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row11_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row11_col5 {
#             background-color:  #d4eece;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row12_col2 {
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row12_col3 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row12_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row12_col5 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row13_col2 {
#             background-color:  #edf8ea;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row13_col3 {
#             background-color:  #eff9eb;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row13_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row13_col5 {
#             background-color:  #c3e7bc;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row14_col2 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row14_col3 {
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row14_col4 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_895c8008_80ac_11ea_9678_0242ac1c0002row14_col5 {
#             background-color:  #c1e6ba;

# %% [markdown]
# ## 확진자수 상위 7개국 통계

# %%
cols = confirmed_df.keys()

# %%
# pandas loc slice
# loc [row slice, cols slice]

confirmed_df.loc[:, cols[4]:cols[-1]]
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  ...  4/13/20  4/14/20  4/15/20  4/16/20
# 0          0        0        0        0  ...      665      714      784      840
# 1          0        0        0        0  ...      467      475      494      518
# 2          0        0        0        0  ...     1983     2070     2160     2268
# 3          0        0        0        0  ...      646      659      673      673
# 4          0        0        0        0  ...       19       19       19       19
# ..       ...      ...      ...      ...  ...      ...      ...      ...      ...
# 259        0        0        0        0  ...        1        1        1        1
# 260        0        0        0        0  ...        4        4        4        4
# 261        0        0        0        0  ...        6        6        6        6
# 262        0        0        0        0  ...        4        4        4        4
# 263        0        0        0        0  ...        1        1        1        1
#
# [264 rows x 86 columns]

# %%
confirmed = confirmed_df.loc[:, cols[4]:cols[-1]]
deaths = deaths_df.loc[:, cols[4]:cols[-1]]
recoveries = recoveries_df.loc[:, cols[4]:cols[-1]]

# %%
# 날짜별 요약을 위한 사전 준비
dates = confirmed.keys()

# 전체 리스트
world_cases = []
total_deaths = [] 
mortality_rate = []
recovery_rate = [] 
total_recovered = [] 
total_active = [] 

# 7개국 확진자 리스트
china_cases = [] 
italy_cases = []
us_cases = [] 
spain_cases = [] 
france_cases = [] 
germany_cases = [] 
uk_cases = [] 

# 7개국 사망자 리스트
china_deaths = [] 
italy_deaths = []
us_deaths = [] 
spain_deaths = [] 
france_deaths = [] 
germany_deaths = [] 
uk_deaths = [] 

# 7개국 완치자 리스트
china_recoveries = [] 
italy_recoveries = []
us_recoveries = [] 
spain_recoveries = [] 
france_recoveries = [] 
germany_recoveries = [] 
uk_recoveries = []

# %%
for i in dates:
    confirmed_sum = confirmed[i].sum()
    death_sum = deaths[i].sum()
    recovered_sum = recoveries[i].sum()
    
    # confirmed, deaths, recovered, and active
    world_cases.append(confirmed_sum)
    total_deaths.append(death_sum)
    total_recovered.append(recovered_sum)
    total_active.append(confirmed_sum-death_sum-recovered_sum)
    
    # calculate rates
    mortality_rate.append(death_sum/confirmed_sum)
    recovery_rate.append(recovered_sum/confirmed_sum)

    # case studies 
    china_cases.append(confirmed_df[confirmed_df['Country/Region']=='China'][i].sum())
    italy_cases.append(confirmed_df[confirmed_df['Country/Region']=='Italy'][i].sum())
    us_cases.append(confirmed_df[confirmed_df['Country/Region']=='US'][i].sum())
    spain_cases.append(confirmed_df[confirmed_df['Country/Region']=='Spain'][i].sum())
    france_cases.append(confirmed_df[confirmed_df['Country/Region']=='France'][i].sum())
    germany_cases.append(confirmed_df[confirmed_df['Country/Region']=='Germany'][i].sum())
    uk_cases.append(confirmed_df[confirmed_df['Country/Region']=='United Kingdom'][i].sum())
    
    china_deaths.append(deaths_df[deaths_df['Country/Region']=='China'][i].sum())
    italy_deaths.append(deaths_df[deaths_df['Country/Region']=='Italy'][i].sum())
    us_deaths.append(deaths_df[deaths_df['Country/Region']=='US'][i].sum())
    spain_deaths.append(deaths_df[deaths_df['Country/Region']=='Spain'][i].sum())
    france_deaths.append(deaths_df[deaths_df['Country/Region']=='France'][i].sum())
    germany_deaths.append(deaths_df[deaths_df['Country/Region']=='Germany'][i].sum())
    uk_deaths.append(deaths_df[deaths_df['Country/Region']=='United Kingdom'][i].sum())
    
    china_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='China'][i].sum())
    italy_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='Italy'][i].sum())
    us_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='US'][i].sum())
    spain_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='Spain'][i].sum())
    france_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='France'][i].sum())
    germany_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='Germany'][i].sum())
    uk_recoveries.append(recoveries_df[recoveries_df['Country/Region']=='United Kingdom'][i].sum())

# %%
def daily_increase(data):
    d = [] 
    for i in range(len(data)):
        if i == 0:
            d.append(data[0])
        else:
            d.append(data[i]-data[i-1])
    return d

# %%
# confirmed cases
world_daily_increase = daily_increase(world_cases)
china_daily_increase = daily_increase(china_cases)
italy_daily_increase = daily_increase(italy_cases)
us_daily_increase = daily_increase(us_cases)
spain_daily_increase = daily_increase(spain_cases)
france_daily_increase = daily_increase(france_cases)
germany_daily_increase = daily_increase(germany_cases)
uk_daily_increase = daily_increase(uk_cases)

# deaths
world_daily_death = daily_increase(total_deaths)
china_daily_death = daily_increase(china_deaths)
italy_daily_death = daily_increase(italy_deaths)
us_daily_death = daily_increase(us_deaths)
spain_daily_death = daily_increase(spain_deaths)
france_daily_death = daily_increase(france_deaths)
germany_daily_death = daily_increase(germany_deaths)
uk_daily_death = daily_increase(uk_deaths)

# recoveries
world_daily_recovery = daily_increase(total_recovered)
china_daily_recovery = daily_increase(china_recoveries)
italy_daily_recovery = daily_increase(italy_recoveries)
us_daily_recovery = daily_increase(us_recoveries)
spain_daily_recovery = daily_increase(spain_recoveries)
france_daily_recovery = daily_increase(france_recoveries)
germany_daily_recovery = daily_increase(germany_recoveries)
uk_daily_recovery = daily_increase(uk_recoveries)

# %%
days_since_1_22 = np.array([i for i in range(len(dates))]).reshape(-1, 1)
world_cases = np.array(world_cases).reshape(-1, 1)
total_deaths = np.array(total_deaths).reshape(-1, 1)
total_recovered = np.array(total_recovered).reshape(-1, 1)

# %% [markdown]
# # 미래 예측 10days

# %%
days_in_future = 10
future_forcast = np.array([i for i in range(len(dates)+days_in_future)]).reshape(-1, 1)
adjusted_dates = future_forcast[:-10]

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start, '%m/%d/%Y')
future_forcast_dates = []
for i in range(len(future_forcast)):
    future_forcast_dates.append((start_date + datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
X_train_confirmed, X_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1_22, world_cases, test_size=0.10, shuffle=False)

# %% [markdown]
# ## SVM

# %%
svm_confirmed = SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1,degree=5, C=0.1)
svm_confirmed.fit(X_train_confirmed, y_train_confirmed)
svm_pred = svm_confirmed.predict(future_forcast)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svm_test_pred = svm_confirmed.predict(X_test_confirmed)
plt.plot(y_test_confirmed)
plt.plot(svm_test_pred)
plt.legend(['Test Data', 'SVM Predictions'])
print('MAE:', mean_absolute_error(svm_test_pred, y_test_confirmed))
print('MSE:',mean_squared_error(svm_test_pred, y_test_confirmed))
# Out:
# MAE: 90745.437886391
# MSE: 15457583312.160719

# %% [markdown]
# ## Polynomial Regression

# %%
poly = PolynomialFeatures(degree=3)
poly_X_train_confirmed = poly.fit_transform(X_train_confirmed)
poly_X_test_confirmed = poly.fit_transform(X_test_confirmed)
poly_future_forcast = poly.fit_transform(future_forcast)

bayesian_poly = PolynomialFeatures(degree=4)
bayesian_poly_X_train_confirmed = bayesian_poly.fit_transform(X_train_confirmed)
bayesian_poly_X_test_confirmed = bayesian_poly.fit_transform(X_test_confirmed)
bayesian_poly_future_forcast = bayesian_poly.fit_transform(future_forcast)

# %%
linear_model = LinearRegression(normalize=True, fit_intercept=True)
linear_model.fit(poly_X_train_confirmed, y_train_confirmed)
test_linear_pred = linear_model.predict(poly_X_test_confirmed)
linear_pred = linear_model.predict(poly_future_forcast)
print('MAE:', mean_absolute_error(test_linear_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_linear_pred, y_test_confirmed))
# Out:
# MAE: 60597.00667959992
# MSE: 7055687107.962116

# %%
plt.plot(y_test_confirmed)
plt.plot(test_linear_pred)
plt.legend(['Test Data', 'Polynomial Regression Predictions'])

# %% [markdown]
# ## Bayesian Ridge Regression

# %%
tol = [1e-4, 1e-3, 1e-2]
alpha_1 = [1e-7, 1e-6, 1e-5, 1e-4]
alpha_2 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_1 = [1e-7, 1e-6, 1e-5, 1e-4]
lambda_2 = [1e-7, 1e-6, 1e-5, 1e-4]

bayesian_grid = {'tol': tol, 'alpha_1': alpha_1, 'alpha_2' : alpha_2, 'lambda_1': lambda_1, 'lambda_2' : lambda_2}

bayesian = BayesianRidge(fit_intercept=False, normalize=True)
bayesian_search = RandomizedSearchCV(bayesian, bayesian_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=40, verbose=1)
bayesian_search.fit(bayesian_poly_X_train_confirmed, y_train_confirmed)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    1.3s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=BayesianRidge(alpha_1=1e-06, alpha_2=1e-06,
#                                            alpha_init=None, compute_score=False,
#                                            copy_X=True, fit_intercept=False,
#                                            lambda_1=1e-06, lambda_2=1e-06,
#                                            lambda_init=None, n_iter=300,
#                                            normalize=True, tol=0.001,
#                                            verbose=False),
#                    iid='deprecated', n_iter=40, n_jobs=-1,
#                    param_distributions={'alpha_1': [1e-07, 1e-06, 1e-05,
#                                                     0.0001],
#                                         'alpha_2': [1e-07, 1e-06, 1e-05,
#                                                     0.0001],
#                                         'lambda_1': [1e-07, 1e-06, 1e-05,
#                                                      0.0001],
#                                         'lambda_2': [1e-07, 1e-06, 1e-05,
#                                                      0.0001],
#                                         'tol': [0.0001, 0.001, 0.01]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
bayesian_search.best_params_
# Out:
# {'alpha_1': 0.0001,
#  'alpha_2': 0.0001,
#  'lambda_1': 1e-06,
#  'lambda_2': 0.0001,
#  'tol': 0.0001}

# %%
bayesian_confirmed = bayesian_search.best_estimator_
test_bayesian_pred = bayesian_confirmed.predict(bayesian_poly_X_test_confirmed)
bayesian_pred = bayesian_confirmed.predict(bayesian_poly_future_forcast)
print('MAE:', mean_absolute_error(test_bayesian_pred, y_test_confirmed))
print('MSE:',mean_squared_error(test_bayesian_pred, y_test_confirmed))
# Out:
# MAE: 53659.53334182532
# MSE: 5172594030.649624

# %%
plt.plot(y_test_confirmed)
plt.plot(test_bayesian_pred)
plt.legend(['Test Data', 'Bayesian Ridge Polynomial Predictions'])

# %%
adjusted_dates = adjusted_dates.reshape(1, -1)[0]
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, world_cases)
plt.title('# of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_deaths)
plt.title('# of Coronavirus Deaths Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_recovered)
plt.title('# of Coronavirus Recoveries Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_active)
plt.title('# of Coronavirus Active Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Active Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, world_daily_increase)
plt.title('World Daily Increases in Confirmed Cases', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, world_daily_death)
plt.title('World Daily Increases in Confirmed Deaths', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.bar(adjusted_dates, world_daily_recovery)
plt.title('World Daily Increases in Confirmed Recoveries', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, np.log10(world_cases))
plt.title('Log of # of Coronavirus Cases Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, np.log10(total_deaths))
plt.title('Log of # of Coronavirus Deaths Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, np.log10(total_recovered))
plt.title('Log of # of Coronavirus Recoveries Over Time', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# # 국가별 plot

# %%
def country_plot(x, y1, y2, y3, y4, country):
    plt.figure(figsize=(16, 9))
    plt.plot(x, y1)
    plt.title('{} Confirmed Cases'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 9))
    plt.bar(x, y2)
    plt.title('{} Daily Increases in Confirmed Cases'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 9))
    plt.bar(x, y3)
    plt.title('{} Daily Increases in Deaths'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

    plt.figure(figsize=(16, 9))
    plt.bar(x, y4)
    plt.title('{} Daily Increases in Recoveries'.format(country), size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

# %%
country_plot(adjusted_dates, china_cases, china_daily_increase, china_daily_death, china_daily_recovery, 'China')

# %%
country_plot(adjusted_dates, italy_cases, italy_daily_increase, italy_daily_death, italy_daily_recovery, 'Italy')

# %%
country_plot(adjusted_dates, us_cases, us_daily_increase, us_daily_death, us_daily_recovery, 'United States')

# %%
country_plot(adjusted_dates, spain_cases, spain_daily_increase, spain_daily_death, spain_daily_recovery, 'Spain')

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, china_cases)
plt.plot(adjusted_dates, italy_cases)
plt.plot(adjusted_dates, us_cases)
plt.plot(adjusted_dates, spain_cases)
plt.plot(adjusted_dates, france_cases)
plt.plot(adjusted_dates, germany_cases)
plt.title('# of Coronavirus Cases', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['China', 'Italy', 'US', 'Spain', 'France', 'Germany'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, china_deaths)
plt.plot(adjusted_dates, italy_deaths)
plt.plot(adjusted_dates, us_deaths)
plt.plot(adjusted_dates, spain_deaths)
plt.plot(adjusted_dates, france_deaths)
plt.plot(adjusted_dates, germany_deaths)

plt.title('# of Coronavirus Deaths', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['China', 'Italy', 'US', 'Spain', 'France', 'Germany'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, china_recoveries)
plt.plot(adjusted_dates, italy_recoveries)
plt.plot(adjusted_dates, us_recoveries)
plt.plot(adjusted_dates, spain_recoveries)
plt.plot(adjusted_dates, france_recoveries)
plt.plot(adjusted_dates, germany_recoveries)
plt.title('# of Coronavirus Recoveries', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.legend(['China', 'Italy', 'US', 'Spain', 'France', 'Germany'], prop={'size': 20})
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %% [markdown]
# # Model Prediction Plot

# %%
def plot_predictions(x, y, pred, algo_name, color):
    plt.figure(figsize=(16, 9))
    plt.plot(x, y)
    plt.plot(future_forcast, pred, linestyle='dashed', color=color)
    plt.title('# of Coronavirus Cases Over Time', size=30)
    plt.xlabel('Days Since 1/22/2020', size=30)
    plt.ylabel('# of Cases', size=30)
    plt.legend(['Confirmed Cases', algo_name], prop={'size': 20})
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show()

# %%
plot_predictions(adjusted_dates, world_cases, svm_pred, 'SVM Predictions', 'purple')

# %%
plot_predictions(adjusted_dates, world_cases, linear_pred, 'Polynomial Regression Predictions', 'orange')

# %%
plot_predictions(adjusted_dates, world_cases, bayesian_pred, 'Bayesian Ridge Regression Predictions', 'green')

# %%
plt.figure(figsize=(16, 9))
plt.plot(adjusted_dates, total_deaths, color='r')
plt.plot(adjusted_dates, total_recovered, color='green')
plt.legend(['death', 'recoveries'], loc='best', fontsize=20)
plt.title('# of Coronavirus Cases', size=30)
plt.xlabel('Days Since 1/22/2020', size=30)
plt.ylabel('# of Cases', size=30)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()
